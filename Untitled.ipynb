# %%
import pandas as pd

# %%
data = pd.read_csv("./05to12_Iquery_WNVData.csv")

# %%
data.head()
# Out:
#            Disease YearText  Year StateOrCounty  IL              Race  \
# 0  West Nile Virus     Year  2011             S  IL  BlackAfricanAmer
# 1  West Nile Virus     Year  2011             S  IL  BlackAfricanAmer
# 2  West Nile Virus     Year  2011             S  IL    Multiple Races
# 3  West Nile Virus     Year  2011             S  IL             Other
# 4  West Nile Virus     Year  2011             S  IL           Unknown
#
#             Ethnicity  Gender AgeGroupText     AgeGroup  Count
# 0    NotHispNotLatino    Male        CD5yr  20-24 Years      1
# 1    NotHispNotLatino    Male        CD5yr   65 + Years      1
# 2    NotHispNotLatino  Female        CD5yr   65 + Years      1
# 3  UnkwnNotClassified    Male        CD5yr  60-64 Years      1
# 4  UnkwnNotClassified  Female        CD5yr  35-39 Years      1

# %%
Cook = data[data.isin(["Cook"]).any(axis=1)]
Cook
# Out:
#              Disease YearText  Year StateOrCounty    IL              Race  \
# 104  West Nile Virus     Year  2005             C  Cook             Asian
# 105  West Nile Virus     Year  2005             C  Cook             Asian
# 106  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 107  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 108  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 109  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 110  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 111  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 112  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 113  West Nile Virus     Year  2005             C  Cook             Other
# 114  West Nile Virus     Year  2005             C  Cook             Other
# 115  West Nile Virus     Year  2005             C  Cook             Other
# ...

# %%
Cook2005= Cook[Cook['Year'].isin(['2005'])]
Cook2005
# Out:
#              Disease YearText  Year StateOrCounty    IL              Race  \
# 104  West Nile Virus     Year  2005             C  Cook             Asian
# 105  West Nile Virus     Year  2005             C  Cook             Asian
# 106  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 107  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 108  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 109  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 110  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 111  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 112  West Nile Virus     Year  2005             C  Cook  BlackAfricanAmer
# 113  West Nile Virus     Year  2005             C  Cook             Other
# 114  West Nile Virus     Year  2005             C  Cook             Other
# 115  West Nile Virus     Year  2005             C  Cook             Other
# ...

# %%
Cook2005.Count.sum()
# Out:
# 134L

# %%
30 + 20 + 16 + 6 +15 + 12 + 11 + 10 +8 + 6
# Out:
# 134

# %%
Cook2006= Cook[Cook['Year'].isin(['2006'])]
Cook2006.Count.sum()
# Out:
# 85L

# %%
Cook2007= Cook[Cook['Year'].isin(['2007'])]
Cook2007.Count.sum()
# Out:
# 33L

# %%
Cook2008= Cook[Cook['Year'].isin(['2008'])]
Cook2008.Count.sum()
# Out:
# 9L

# %%
Cook2009= Cook[Cook['Year'].isin(['2009'])]
Cook2009.Count.sum()
# Out:
# 1L

# %%
Cook2010= Cook[Cook['Year'].isin(['2010'])]
Cook2010.Count.sum()
# Out:
# 30L

# %%
Cook2011= Cook[Cook['Year'].isin(['2011'])]
Cook2011.Count.sum()
# Out:
# 22L

# %%
Cook2012= Cook[Cook['Year'].isin(['2012'])]
Cook2012.Count.sum()
# Out:
# 174L

# %%
Cook2005_2012 = Cook2005.Count.sum()+ Cook2006.Count.sum() + Cook2007.Count.sum() + Cook2008.Count.sum()+Cook2009.Count.sum()+Cook2010.Count.sum()+Cook2011.Count.sum()+Cook2012.Count.sum()
Cook2005_2012
# Out:
# 488L
